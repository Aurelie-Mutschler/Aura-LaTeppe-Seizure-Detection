# %%
import os
import glob

import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.io as pio

# %%
# List of files
files_path = "/home/DATA/output/cons-v0_6/cons_PAT_*.csv"
# Path to dir to save figures
figures_path = 'figures/'
# Path to output files
res_path = "res/patient_files/"

# %%
# Create list of files' paths
patient_files = glob.glob(files_path, recursive = True)
df_files = pd.DataFrame(patient_files, columns = ['path'])

def extract_patient_id(path):
    return int(path.split('PAT_')[1].split('_Annotations')[0])
df_files['patient_id'] = df_files['path'].apply(extract_patient_id)

def extract_session_id(path):
    return int(path.split('_s')[0].split('_')[-1])
df_files['session_id'] = df_files['path'].apply(extract_session_id)

def extract_segment_id(path):
    return int(path.split('_s')[1].split('.csv')[0])
df_files['segment_id'] = df_files['path'].apply(extract_segment_id)

df_files = df_files.sort_values(by = ['patient_id', 'session_id', 'segment_id']).reset_index(drop=True)
display(df_files)
# Out:
#                                                   path  patient_id  \
# 0    /home/DATA/output/cons-v0_6/cons_PAT_7_Annotat...           7
# 1    /home/DATA/output/cons-v0_6/cons_PAT_7_Annotat...           7
# 2    /home/DATA/output/cons-v0_6/cons_PAT_7_Annotat...           7
# 3    /home/DATA/output/cons-v0_6/cons_PAT_7_Annotat...           7
# 4    /home/DATA/output/cons-v0_6/cons_PAT_7_Annotat...           7
# ..                                                 ...         ...
# 130  /home/DATA/output/cons-v0_6/cons_PAT_45_Annota...          45
# 131  /home/DATA/output/cons-v0_6/cons_PAT_45_Annota...          45
# 132  /home/DATA/output/cons-v0_6/cons_PAT_45_Annota...          45
# 133  /home/DATA/output/cons-v0_6/cons_PAT_45_Annota...          45
# 134  /home/DATA/output/cons-v0_6/cons_PAT_45_Annota...          45
#
#      session_id  segment_id
# 0           844          10
# 1          3838           1
# 2          3838           3
# 3          3838           4
# 4          4545           1
# ..          ...         ...
# 130       59090           4
# 131       59090           5
# 132       59090           6
# 133       59090           7
# 134       59090           8
#
# [135 rows x 4 columns]
